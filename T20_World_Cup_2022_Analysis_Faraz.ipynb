# %% [markdown]
# <a href="https://colab.research.google.com/github/FACODES/2022-T20-world-cup-cricket-Analysis/blob/main/T20_World_Cup_2022_Analysis_Faraz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.templates.default=  "plotly_white"

data=pd.read_csv("/content/t20-world-cup-22.csv")

data
# Out:
#                venue         team1         team2       stage   toss winner  \
# 0                SCG   New Zealand     Australia    Super 12     Australia
# 1      Optus Stadium   Afghanistan       England    Super 12       England
# 2   Blundstone Arena       Ireland     Sri lanka    Super 12       Ireland
# 3                MCG      Pakistan         India    Super 12         India
# 4   Blundstone Arena    Bangladesh   Netherlands    Super 12   Netherlands
# 5   Blundstone Arena      Zimbabwe  South Africa    Super 12      Zimbabwe
# 6      Optus Stadium     Sri lanka     Australia    Super 12     Australia
# 7                MCG       Ireland       England    Super 12       England
# 8                MCG   New Zealand   Afghanistan    Super 12           NaN
# 9                SCG  South Africa    Bangladesh    Super 12  South Africa
# 10               SCG         India   Netherlands    Super 12         India
# ...

# %% [markdown]
# # **Now let's look at the number of matches won by each team in the World cup**

# %%
figure=px.bar(data,x=data["winner"],
                               title="Number of Matches won by teams in t20 World Cup 2022")

figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **As England won the t20 world cup 2022,England won 5 matches.Both Pakistan and India won 4 matches**

# %% [markdown]
# # **Now let's have a look at the number of matches won by Batting First or Second in the world Cup**

# %%
won_by=data["won by"].value_counts()
labels=won_by.index 
counts=won_by.values 
colors=["gold","lightgreen"]

fig=go.Figure(data=[go.Pie(labels=labels,values=counts)])
fig.update_layout(title_text="Number of Matches Won By Runs or Wickets")
fig.update_traces(hoverinfo="label+percent",textinfo="value",textfont_size=30,
                  marker=dict(colors=colors,line=dict(color="black",width=3)))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **16 matches were won by Batting First team and 13 matches were won by chasing**

# %% [markdown]
# # **let's have a look at the toss decisions by teams in the world cup:**

# %%
toss=data["toss decision"].value_counts()
labels=toss.index 
counts=toss.values 
colors=["skyblue","yellow"]

fig=go.Figure(data=[go.Pie(labels=labels,values=counts)])
fig.update_layout(title_text="Toss Decisions in t20 World Cup 2022")
fig.update_traces(hoverinfo="label+percent",textinfo="value",textfont_size=30,
                  marker=dict(colors=colors,line=dict(color="black",width=3)))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **In 17 matches,the teams decided to bat first and in 13 matches .the teams decided to bowl first.**

# %% [markdown]
# # **Let's find out the top scorers in the world cup:**

# %%
figure=px.bar(data,x=data["top scorer"],
              y=data["highest score"],
              color=data["highest score"],
              title="Top Scores in t20 World Cup 2022")

figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **So,Virat Kohli scored the highest in 3 matches.**

# %% [markdown]
# # **Let's find out the number of player of the match awards:**

# %%
figure=px.bar(data,x=data["player of the match"],
              title="Player of the match Awards in the World Cup")

figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Virat,Sam,Taskin and Yadav ,Shadab khan got the player of the match 2 times.**

# %% [markdown]
# # **Let's find out the bowlers with best bowling figures at the End of the matches:**

# %%
figure=px.bar(data,x=data["best bowler"],
              title="Best Bowlers in the World Cup")

figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Sam Curan was the best bowler in 3 matches.Undoubtedly,he deserved to be the player of the tournament.**

# %% [markdown]
# #HomeWork:
#
# 1.You have to compare the runs scored in the first innings and second innings in every stadium in the world cup.
#
# 2.You have to compare the number of wickets lost in first innings and second innings in every stadium in the world cup.

# %% [markdown]
#  Let's compare the runs scored in the first innings and second innings in every stadium in the world cup.

# %%
fig=go.Figure()
fig.add_trace(go.Bar(
    x=data["venue"],
    y=data["first innings score"],
    name="First Innings Runs",
    marker_color="blue"
))

fig.add_trace(go.Bar(
    x=data["venue"],
    y=data["second innings score"],
    name="Second Innings Runs",
    marker_color="red"
))

fig.update_layout(barmode="group",
                  xaxis_tickangle=45,
                  title="Best Stadiums to Bat First oe Chase")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **So SCG was the only stadium in the world cup that was best for batting first.Other Stadiums didn't make much difference while batting first or chasing.**

# %% [markdown]
# # let's  compare the number of wickets lost in first innings and second innings in every stadium in the world cup.

# %%
fig=go.Figure()
fig.add_trace(go.Bar(
    x=data["venue"],
    y=data["first innings wickets"],
    name='First Innings Wickets',
    marker_color='blue'
))
fig.add_trace(go.Bar(
    x=data["venue"],
    y=data["second innings wickets"],
    name='Second Innings Wickets',
    marker_color='red'
))
fig.update_layout(barmode='group', 
                  xaxis_tickangle=-45, 
                  title="Best Statiums to Bowl First or Defend")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **SCG was the best Stadium to bowl while defending the Target,while the Optus stadium was the best stadium to bowl first.**

# %% [markdown]
# # **Summary:**

# %% [markdown]
# # England won th most number of matches
#
# # Virat Kohli Scored Highest in the most number of matches
#
# # Sam Curran was the best bowler in the most number of matches
#
# # More teams won by batting first
#
# # More teams decided to Bat First
#
# # SCG was the best stadium to bat first
#
# # SCG was the best stadium to defend the target in the world cup
#
# # The optus stadium was the best stadium to bowl first

# %% [markdown]
# # **#Create an Github ACcount.**

# %%
fig=go.Figure()
fig.add_trace(go.Bar(
    x=data["venue"],
    y=data["highest score"],
    name='highest score',
    marker_color='yellow'
))
fig.add_trace(go.Bar(
    x=data["stage"],
    y=data["highest score"],
    name='Highest Score',
    marker_color='orange'
))
fig.update_layout(barmode='group', 
                  xaxis_tickangle=45, 
                  title="HIGHEST SCORE")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Bar(
    x=data["best bowler"],
    y=data["best bowling figure"],
    name='bowling figure',
    marker_color='blue'
))
fig.add_trace(go.Bar(
    x=data["best bowler"],
    y=data["highest score"],
    name='highest score for best bowler',
    marker_color='yellow'
))
fig.update_layout(barmode='group', 
                  xaxis_tickangle=-45, 
                  title="")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Bar(
    x=data["top scorer"],
    y=data["highest score"],
    name='top scorer highest score',
    marker_color='yellow'
))
fig.add_trace(go.Bar(
    x=data["winner"],
    y=data["highest score"],
    name='highest score for the winners',
    marker_color='black'
))
fig.update_layout(barmode='group', 
                  xaxis_tickangle=-45, 
                  title="")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data
# Out:
#                venue         team1         team2       stage   toss winner  \
# 0                SCG   New Zealand     Australia    Super 12     Australia
# 1      Optus Stadium   Afghanistan       England    Super 12       England
# 2   Blundstone Arena       Ireland     Sri lanka    Super 12       Ireland
# 3                MCG      Pakistan         India    Super 12         India
# 4   Blundstone Arena    Bangladesh   Netherlands    Super 12   Netherlands
# 5   Blundstone Arena      Zimbabwe  South Africa    Super 12      Zimbabwe
# 6      Optus Stadium     Sri lanka     Australia    Super 12     Australia
# 7                MCG       Ireland       England    Super 12       England
# 8                MCG   New Zealand   Afghanistan    Super 12           NaN
# 9                SCG  South Africa    Bangladesh    Super 12  South Africa
# 10               SCG         India   Netherlands    Super 12         India
# ...
